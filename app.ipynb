# %%
from openai import OpenAI

# openai.api_key = "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"
client = OpenAI(api_key="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")

def generate_survey(topic, num_questions=12):
    prompt = f"Generate {num_questions} survey questions on the topic: {topic}. Include multiple choice, checkbox, linear scale, dropdown, and open-ended questions."
    
    response = client.chat.completions.create(
        messages=[{
            "role": "user",
            "content": prompt,
        }],
        model="gpt-4o-mini",
    )
    
    return response.choices[0].message.content

# %%
from IPython.display import display, Markdown

def display_survey(survey_text):
    display(Markdown(survey_text))
    
topic = input("Please enter your topic: ")
num_questions = 12

# Sorğunu yarat
survey = generate_survey(topic, num_questions)

# Sorğunu notebook-da göstər
display_survey(survey)
# Out:
# Sure! Here are 12 survey questions on the topic of Islam that incorporate various question types:
#
# ### Multiple Choice
# 1. **What is your primary source of knowledge about Islam?**
#    - a) Books
#    - b) Online articles
#    - c) Educational institutions
#    - d) Friends or family
#    - e) Personal experiences
#    - f) Other (please specify)
#
# ### Checkbox
# 2. **Which aspects of Islam are you familiar with? (Select all that apply)**
#    - [ ] The Five Pillars of Islam
#    - [ ] Major Islamic festivals (e.g., Eid al-Fitr, Eid al-Adha)
#    - [ ] Islamic history
#    - [ ] Islamic law (Sharia)
#    - [ ] Different sects of Islam (e.g., Sunni, Shia)
#    - [ ] Famous Islamic scholars and thinkers
#
# ### Linear Scale
# 3. **On a scale of 1 to 5, how would you rate your understanding of Islamic beliefs and practices?**
#    - 1: No understanding
#    - 2: Minimal understanding
#    - 3: Moderate understanding
#    - 4: Good understanding
#    - 5: Excellent understanding
#
# ### Dropdown
# 4. **What is your religious affiliation?**
#    - [ ] Islam
#    - [ ] Christianity
#    - [ ] Judaism
#    - [ ] Hinduism
#    - [ ] Buddhism
#    - [ ] Atheist
#    - [ ] Agnostic
#    - [ ] Other (please specify)
#
# ### Open-ended
# 5. **What do you think are common misconceptions about Islam?**
#
# ### Multiple Choice
# 6. **Which of the following statements best describes your level of participation in Islamic practices (if any)?**
#    - a) I actively practice Islam (prayer, fasting, etc.)
#    - b) I identify as a Muslim but do not actively practice
#    - c) I am interested in learning about Islam
#    - d) I do not identify with Islam but respect it
#    - e) I have no interest in Islam
#
# ### Checkbox
# 7. **What topics related to Islam would you like to learn more about? (Select all that apply)**
#    - [ ] Islamic history
#    - [ ] Islamic theology
#    - [ ] Contemporary issues in the Muslim world
#    - [ ] Interfaith relations
#    - [ ] Islamic arts and culture
#    - [ ] Islamic philosophy
#
# ### Linear Scale
# 8. **How strongly do you agree with the following statement: "Islam promotes peace and coexistence among different cultures."**
#    - 1: Strongly disagree
#    - 2: Disagree
#    - 3: Neutral
#    - 4: Agree
#    - 5: Strongly agree
#
# ### Dropdown
# 9. **In your opinion, how accurately is Islam represented in mainstream media?**
#    - [ ] Very accurately
#    - [ ] Somewhat accurately
#    - [ ] Neutral
#    - [ ] Somewhat inaccurately
#    - [ ] Very inaccurately
#
# ### Open-ended
# 10. **What personal experiences or interactions have shaped your view of Islam?**
#
# ### Multiple Choice
# 11. **How often do you engage with Islamic literature or media?**
#    - a) Frequently (daily/weekly)
#    - b) Occasionally (monthly)
#    - c) Rarely (a few times a year)
#    - d) Never
#
# ### Checkbox
# 12. **Which of the following do you think are the primary issues facing Muslims today? (Select all that apply)**
#    - [ ] Islamophobia
#    - [ ] Economic challenges
#    - [ ] Political instability in Muslim-majority countries
#    - [ ] Misrepresentation in media
#    - [ ] Inter-sect tensions
#    - [ ] Other (please specify)
#
# These questions aim to gather a comprehensive understanding of respondents' knowledge, perceptions, and experiences related to Islam.
